# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading images using OpenCV
#
# In OpenCV the function cv2.imread() is used to read an image with file extension like(JPG,JPEG,PNG) etc. It also allow us to read images with grayscale and Alpha channel also. There different approches/tecniques are available to read an image in different format like:
# The function cv2.IMREAD_GRAYSCALE() is used to read an color image into gray scale. The function cv2.IMREAD_COLOR() is used to load an color image and the function cv2.IMREAD_UNCHANGED() is used to load a image with alpha channel

# %%
img = "/content/drive/MyDrive/Datasets/Image Dataset/dinosaur/dinasosaurus.webp"
image = Image.open(img)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# # Read images in different way using OpenCV
#
# By reading an image into gray scale it will help us by making the image more simple with having just 1 color channel and remove the complexity that we have faced to read normal color image. It also gives us a better performance for object detection and feature extraction.

# %%
import cv2

image_path = "/content/drive/MyDrive/Datasets/Image Dataset/dinosaur/dinasosaurus.webp"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# By using the cmap(colormap) we also able to read image into a gray scale mood also.

# %%
## Read image as gray scale.
img = cv2.imread("/content/drive/MyDrive/Datasets/Image Dataset/dinosaur/dinasosaurus.webp", 0)
plt.imshow(img, cmap="gray")
plt.axis('off')
plt.show()

# %%
# read images into color scale mode

image_path = "/content/drive/MyDrive/Datasets/Image Dataset/dinosaur/dinasosaurus.webp"
image = cv2.imread(image_path, cv2.IMREAD_COLOR)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# There is also an approach to read an image with a color from the color format of RGB. We able to fixed a custom number for the images to represent.
#
# Break dowm the images beased on the color channel of BGR format to read the picture individually with color channel

# %%
img = cv2.imread("/content/drive/MyDrive/Datasets/Image Dataset/dinosaur/dinasosaurus.webp")
B, G, R = cv2.split(img)
print(B.shape)
plt.imshow(B)
plt.axis('off')
plt.show()
# Out:
# (1000, 1600)

# %%
plt.imshow(G)
plt.axis('off')
plt.show()

# %%
plt.imshow(R)
plt.show()

# %%
# Split the image into the B,G,R components

BGR_RGB = cv2.imread("/content/drive/MyDrive/Datasets/Image Dataset/dinosaur/dinasosaurus.webp", cv2.IMREAD_COLOR)
b, g, r = cv2.split(BGR_RGB)
plt.figure(figsize=[25, 7])

plt.subplot(141)
plt.imshow(r, cmap='gray')
plt.title('Red Channel')

plt.subplot(142)
plt.imshow(b, cmap='gray')
plt.title('Blue Channel')

plt.subplot(143)
plt.imshow(g, cmap='gray')
plt.title('Green Channel')

imgMerged = cv2.merge((b, g, r))

#show the mereged output
plt.subplot(144)
plt.imshow(imgMerged[:, :, ::-1])
plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')
