# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("result.csv")
df.head()
# Out:
#    cgpa  resume_score  passed
# 0  5.12         65.78       0
# 1  7.89         82.34       1
# 2  6.45         55.23       0
# 3  8.12         91.45       1
# 4  4.56         42.67       0

# %%
sns.scatterplot(
    data=df, 
    x= 'cgpa',
    y= 'resume_score',
    hue='passed'
)
plt.show()

# %%
x = df.iloc[:, 0:2]
y = df.iloc[:, -1]

# %%
from sklearn.linear_model import Perceptron

# %%
P = Perceptron()

# %%
model = P.fit(x, y)
model
# Out:
# Perceptron()

# %%
print("Value od W1, W2:")
P.coef_
# Out:
# Value od W1, W2:
# array([[-239.44,   11.09]])

# %%
print("Value of Bias(b):")
P.intercept_
# Out:
# Value of Bias(b):
# array([-221.])
